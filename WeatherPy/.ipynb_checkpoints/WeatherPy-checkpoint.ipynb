# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from scipy import stats

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

#-------------------------------------------
import os
import gmaps
import json
from api_keys import g_key
#-------------------------------------------
# !pip install citipy
# !pip install census
# !pip install us
# !jupyter nbextension enable --py gmaps
# Out:
# Requirement already satisfied: citipy in c:\users\aclif\anaconda3\envs\pythondata\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\aclif\anaconda3\envs\pythondata\lib\site-packages (from citipy) (0.16)
# Requirement already satisfied: census in c:\users\aclif\anaconda3\envs\pythondata\lib\site-packages (0.8.14)
# Requirement already satisfied: future in c:\users\aclif\anaconda3\envs\pythondata\lib\site-packages (from census) (0.18.2)
# Requirement already satisfied: requests>=1.1.0 in c:\users\aclif\anaconda3\envs\pythondata\lib\site-packages (from census) (2.23.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\aclif\anaconda3\envs\pythondata\lib\site-packages (from requests>=1.1.0->census) (2.9)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\aclif\anaconda3\envs\pythondata\lib\site-packages (from requests>=1.1.0->census) (1.25.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aclif\anaconda3\envs\pythondata\lib\site-packages (from requests>=1.1.0->census) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\aclif\anaconda3\envs\pythondata\lib\site-packages (from requests>=1.1.0->census) (3.0.4)
# Requirement already satisfied: us in c:\users\aclif\anaconda3\envs\pythondata\lib\site-packages (2.0.2)
# Requirement already satisfied: jellyfish==0.6.1 in c:\users\aclif\anaconda3\envs\pythondata\lib\site-packages (from us) (0.6.1)
# Enabling notebook extension jupyter-gmaps/extension...
#       - Validating: ok

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
latlng_cities = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)

lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    latlng_cities.append(city)        
        
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count
#cities
len(cities)
#latlng_cities
#len(latlng_cities)
# Out:
# 625

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# cities = pd.DataFrame(cities, columns=["city"])
# cities["lat"] = ""
# cities["lon"] = ""
# cities["main"] = ""
# cities["description"] = ""
# cities["temp"] = ""
# cities["pressure"] = ""
# cities["humidity"] = ""
# cities["temp_min"] = ""
# cities["temp_max"] = ""
# cities["speed"] = ""
# cities["deg"] = ""
# cities["clouds"] = ""
# cities.head()
cities_arr = []

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
for index, city in enumerate(cities):
#for city in cities:
        url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
        query_url = f"{url}&q={city}"
#         city = row["city"]
        response = requests.get(query_url)
        response = response.json()
    
        try:
            lat = response["coord"]["lat"]
            lng = response["coord"]["lon"]
            main = response["weather"][0]["main"]
            description = response["weather"][0]["description"]
            temp = response["main"]["temp"]
            pressure = response["main"]["pressure"]
            humidity = response["main"]["humidity"]
            temp_min = response["main"]["temp_min"]
            temp_max = response["main"]["temp_max"]
            wind_speed = response["wind"]["speed"]
            wind_deg = response["wind"]["deg"]
            clouds = response["clouds"]["all"]
            country = response["sys"]["country"]
            dt = response["dt"]
            cities_arr.append({"City": city,
                               "Lat": lat,
                               "Lng": lng,
                               "Main": main,
                               "Description": description,
                               "Temperature": temp,
                               "Pressure": pressure,
                               "Humidity": humidity,
                               "Min Temp": temp_min,
                               "Max Temp": temp_max,
                               "Wind Speed": wind_speed,
                               "Wind Deg": wind_deg,
                               "Cloud Layer": clouds,
                               "Country": country,
                               "Date": dt})

            #print("Processing city #" str(index) + ": " + city)
            print("Processing city #" + city)
            
        except (KeyError, IndexError):
            print("City not found. Skipping ... ")
            pass
            #https://stackoverflow.com/questions/38707513/ignoring-an-error-message-to-continue-with-the-loop-in-python
# Out:
# Processing city #auki
# Processing city #kristiansund
# Processing city #kaeo
# Processing city #rikitea
# Processing city #castro
# Processing city #arraial do cabo
# Processing city #demba
# Processing city #sao joao da barra
# Processing city #barrow
# Processing city #mataura
# City not found. Skipping ...
# Processing city #saint anthony
# Processing city #qaanaaq
# Processing city #darlawn
# Processing city #pangkalanbuun
# Processing city #canning
# Processing city #shubarshi
# Processing city #chuy
# Processing city #sovetskiy
# Processing city #jamestown
# Processing city #new norfolk
# Processing city #ostrovnoy
# City not found. Skipping ...
# Processing city #carballo
# Processing city #mawlaik
# City not found. Skipping ...
# City not found. Skipping ...
# Processing city #kingisepp
# Processing city #husavik
# Processing city #busselton
# Processing city #airai
# Processing city #east london
# Processing city #dikson
# Processing city #nikolskoye
# Processing city #iskateley
# Processing city #bluff
# Processing city #havelock
# Processing city #mar del plata
# Processing city #srednekolymsk
# Processing city #jumla
# Processing city #mackenzie
# Processing city #puerto ayora
# Processing city #vaini
# Processing city #kpandae
# Processing city #rawson
# Processing city #dicabisagan
# Processing city #tasiilaq
# Processing city #khatanga
# Processing city #port elizabeth
# Processing city #butaritari
# Processing city #thompson
# Processing city #cayenne
# Processing city #elumalai
# Processing city #timra
# City not found. Skipping ...
# Processing city #komsomolskiy
# Processing city #bredasdorp
# Processing city #inhambane
# Processing city #czarnkow
# Processing city #sembakung
# Processing city #kodinsk
# Processing city #san patricio
# City not found. Skipping ...
# Processing city #kapaa
# Processing city #shahr-e babak
# Processing city #dubbo
# Processing city #farah
# Processing city #nanortalik
# Processing city #san quintin
# Processing city #gerash
# Processing city #riviere-au-renard
# Processing city #ushuaia
# Processing city #matara
# City not found. Skipping ...
# Processing city #hobart
# Processing city #cape town
# Processing city #carnarvon
# Processing city #albany
# Processing city #katherine
# Processing city #lebu
# Processing city #ranau
# Processing city #chifeng
# Processing city #punta arenas
# Processing city #chapleau
# City not found. Skipping ...
# Processing city #hithadhoo
# Processing city #lorengau
# Processing city #kaitangata
# Processing city #saskylakh
# Processing city #dorogobuzh
# Processing city #harper
# Processing city #constitucion
# Processing city #golden
# Processing city #nome
# Processing city #yellowknife
# Processing city #bokovskaya
# Processing city #ambunti
# Processing city #pangnirtung
# Processing city #sungaipenuh
# Processing city #bathsheba
# Processing city #portland
# Processing city #at-bashi
# Processing city #tatawin
# Processing city #ribeira grande
# Processing city #wanaka
# Processing city #ahuimanu
# Processing city #dabat
# Processing city #port alfred
# Processing city #tautira
# Processing city #pevek
# Processing city #upernavik
# Processing city #dasoguz
# City not found. Skipping ...
# Processing city #komsomolets
# Processing city #slavuta
# Processing city #atuona
# Processing city #batagay
# Processing city #roald
# Processing city #bambous virieux
# Processing city #taman
# Processing city #avarua
# Processing city #plainview
# Processing city #fortuna
# Processing city #oranjemund
# City not found. Skipping ...
# Processing city #north myrtle beach
# Processing city #farafangana
# Processing city #hambantota
# Processing city #cherskiy
# Processing city #sitka
# Processing city #nouadhibou
# Processing city #alice springs
# Processing city #harbour breton
# Processing city #georgetown
# Processing city #alyangula
# City not found. Skipping ...
# Processing city #cap-aux-meules
# Processing city #quesnel
# Processing city #mahebourg
# Processing city #vila velha
# Processing city #maceio
# Processing city #esperance
# Processing city #codrington
# Processing city #benguela
# City not found. Skipping ...
# Processing city #half moon bay
# Processing city #broome
# Processing city #skibbereen
# Processing city #porto belo
# Processing city #sterling
# Processing city #helong
# Processing city #kokopo
# Processing city #salalah
# Processing city #soe
# Processing city #leningradskiy
# Processing city #luang prabang
# Processing city #kodiak
# Processing city #chokurdakh
# Processing city #ponta do sol
# Processing city #souillac
# Processing city #iqaluit
# Processing city #kampot
# Processing city #rohnert park
# Processing city #sao jose da coroa grande
# Processing city #walvis bay
# Processing city #katsuura
# Processing city #mount isa
# Processing city #mogzon
# Processing city #tilichiki
# Processing city #beloha
# City not found. Skipping ...
# Processing city #ilulissat
# Processing city #aripuana
# Processing city #haines junction
# Processing city #christchurch
# Processing city #porto santo
# Processing city #sabha
# Processing city #qingdao
# Processing city #leshukonskoye
# Processing city #hermanus
# Processing city #durban
# City not found. Skipping ...
# Processing city #bourail
# Processing city #hokitika
# Processing city #ucluelet
# Processing city #kirkwall
# Processing city #belize
# Processing city #masallatah
# Processing city #waingapu
# Processing city #hasaki
# Processing city #biak
# City not found. Skipping ...
# Processing city #cidreira
# Processing city #beringovskiy
# Processing city #port lincoln
# Processing city #ixtapa
# Processing city #kingaroy
# Processing city #san cristobal
# City not found. Skipping ...
# Processing city #longyearbyen
# Processing city #acapulco
# Processing city #laguna
# Processing city #magadan
# Processing city #kendari
# Processing city #birao
# Processing city #bereda
# Processing city #muisne
# Processing city #ormara
# Processing city #galesong
# Processing city #atlacomulco
# Processing city #pangoa
# Processing city #port blair
# Processing city #omboue
# Processing city #bubaque
# Processing city #adrar
# Processing city #torbay
# Processing city #alamos
# City not found. Skipping ...
# Processing city #cianorte
# Processing city #porto novo
# Processing city #bardiyah
# Processing city #veshenskaya
# Processing city #xudat
# Processing city #nueva helvecia
# Processing city #san felipe
# Processing city #bilma
# Processing city #hay river
# Processing city #hit
# Processing city #poum
# Processing city #port hardy
# Processing city #dingle
# City not found. Skipping ...
# Processing city #axim
# Processing city #lagoa
# Processing city #krasnogorsk
# Processing city #hilo
# Processing city #severo-kurilsk
# Processing city #severnyy
# City not found. Skipping ...
# Processing city #ancud
# Processing city #ulety
# Processing city #nizhneangarsk
# Processing city #homer
# Processing city #viedma
# Processing city #havoysund
# Processing city #ambilobe
# Processing city #puerto madero
# Processing city #guerrero negro
# Processing city #kaduna
# Processing city #wawa
# Processing city #tuktoyaktuk
# Processing city #velka nad velickou
# Processing city #cabo san lucas
# Processing city #saravena
# Processing city #puerto el triunfo
# Processing city #mayumba
# Processing city #aykhal
# Processing city #port augusta
# Processing city #provideniya
# Processing city #bainbridge
# City not found. Skipping ...
# Processing city #flin flon
# Processing city #warrnambool
# Processing city #bay roberts
# Processing city #brora
# Processing city #high level
# City not found. Skipping ...
# Processing city #japura
# Processing city #dondo
# Processing city #bonavista
# Processing city #qiyang
# Processing city #libenge
# Processing city #caldas novas
# Processing city #prince rupert
# Processing city #strezhevoy
# Processing city #margate
# Processing city #abu samrah
# Processing city #serik
# Processing city #hamilton
# Processing city #corpus christi
# Processing city #tynda
# Processing city #prudnik
# Processing city #roma
# Processing city #zyryanka
# Processing city #athabasca
# City not found. Skipping ...
# Processing city #vila franca do campo
# Processing city #vilyuysk
# Processing city #awjilah
# Processing city #hukuntsi
# Processing city #pimenta bueno
# Processing city #menongue
# Processing city #anloga
# Processing city #norman wells
# Processing city #mitsamiouli
# Processing city #rabo de peixe
# City not found. Skipping ...
# Processing city #caravelas
# Processing city #smithers
# Processing city #kourou
# City not found. Skipping ...
# Processing city #raudeberg
# Processing city #saurimo
# Processing city #saint george
# Processing city #gold coast
# Processing city #salinopolis
# City not found. Skipping ...
# Processing city #moffat
# Processing city #inuvik
# Processing city #mama
# Processing city #kiunga
# Processing city #shache
# Processing city #ayan
# City not found. Skipping ...
# Processing city #madinat sittah uktubar
# Processing city #marion
# Processing city #nizwa
# Processing city #san juan
# Processing city #takoradi
# Processing city #geraldton
# Processing city #tyrma
# Processing city #bengkulu
# Processing city #clyde river
# Processing city #yerbogachen
# Processing city #williams lake
# Processing city #oussouye
# Processing city #zlynka
# Processing city #south lake tahoe
# Processing city #bell ville
# Processing city #saint-augustin
# Processing city #zhigansk
# Processing city #petropavlovsk-kamchatskiy
# Processing city #berlevag
# Processing city #whitehorse
# Processing city #naze
# Processing city #isangel
# Processing city #vaijapur
# Processing city #cooma
# Processing city #barceloneta
# Processing city #nuuk
# Processing city #tongling
# Processing city #kahului
# Processing city #xuddur
# Processing city #morros
# Processing city #karratha
# Processing city #qui nhon
# Processing city #agadez
# Processing city #mount gambier
# Processing city #severo-yeniseyskiy
# Processing city #katobu
# Processing city #altotting
# Processing city #bethel
# Processing city #beitbridge
# Processing city #tenenkou
# Processing city #sciacca
# Processing city #hovd
# Processing city #yablonovo
# Processing city #areia branca
# Processing city #lasa
# Processing city #coromandel
# Processing city #rio gallegos
# Processing city #alihe
# Processing city #sinnamary
# Processing city #hami
# Processing city #eureka
# Processing city #port-gentil
# City not found. Skipping ...
# Processing city #mogadishu
# Processing city #la palma
# Processing city #los llanos de aridane
# Processing city #makakilo city
# Processing city #northam
# Processing city #ballina
# City not found. Skipping ...
# Processing city #ozernovskiy
# Processing city #huntsville
# Processing city #santa lucia
# Processing city #barrhead
# Processing city #altamirano
# Processing city #vredendal
# Processing city #sagua la grande
# Processing city #ayia galini
# Processing city #pacific grove
# Processing city #grindavik
# Processing city #atbasar
# Processing city #hillsborough
# Processing city #grasse
# Processing city #luderitz
# Processing city #avera
# Processing city #chapais
# Processing city #waitati
# Processing city #abilene
# Processing city #kavieng
# Processing city #vysokogornyy
# Processing city #tambacounda
# Processing city #asau
# Processing city #taoudenni
# Processing city #cockburn town
# Processing city #kulaman
# Processing city #krasnoselkup
# Processing city #ust-nera
# Processing city #banjar
# Processing city #fairbanks
# Processing city #safaga
# Processing city #tuatapere
# Processing city #saint-philippe
# Processing city #altay
# Processing city #senneterre
# Processing city #teya
# Processing city #kenai
# Processing city #kruisfontein
# City not found. Skipping ...
# Processing city #mahabad
# Processing city #nantucket
# Processing city #saldanha
# Processing city #jalu
# Processing city #izberbash
# Processing city #jizan
# Processing city #manama
# Processing city #niamtougou
# Processing city #saint stephen
# Processing city #punto fijo
# Processing city #druzhba
# Processing city #huntington
# Processing city #meulaboh
# Processing city #kisangani
# Processing city #victoria
# City not found. Skipping ...
# Processing city #great yarmouth
# Processing city #sola
# Processing city #harstad
# Processing city #narsaq
# Processing city #tateyama
# Processing city #mujiayingzi
# Processing city #rocha
# Processing city #olinda
# Processing city #verkhoyansk
# Processing city #aklavik
# Processing city #bom jesus
# Processing city #melville
# Processing city #fukue
# Processing city #hofn
# Processing city #cheyenne
# Processing city #kishtwar
# Processing city #taunggyi
# Processing city #college
# Processing city #state college
# Processing city #mizdah
# Processing city #kontagora
# City not found. Skipping ...
# Processing city #labuhan
# Processing city #sarai naurang
# Processing city #davila
# Processing city #tirat karmel
# Processing city #lavrentiya
# Processing city #saint-louis
# Processing city #izmalkovo
# Processing city #peoria
# City not found. Skipping ...
# Processing city #andradas
# Processing city #yantal
# Processing city #broken hill
# Processing city #moose factory
# City not found. Skipping ...
# Processing city #bac lieu
# Processing city #necochea
# Processing city #constantine
# Processing city #thunder bay
# Processing city #martapura
# Processing city #mezen
# Processing city #klaksvik
# Processing city #coihaique
# Processing city #synya
# Processing city #huarmey
# Processing city #tambo
# Processing city #townsville
# Processing city #neryungri
# Processing city #sao filipe
# Processing city #talnakh
# City not found. Skipping ...
# Processing city #faanui
# City not found. Skipping ...
# Processing city #lompoc
# Processing city #maputo
# Processing city #dong hoi
# Processing city #khani
# Processing city #miandrivazo
# Processing city #rio grande
# Processing city #santa maria
# Processing city #berdsk
# Processing city #saint-joseph
# Processing city #snasa
# Processing city #lujan
# Processing city #gizo
# Processing city #sosva
# City not found. Skipping ...
# Processing city #padang
# Processing city #umuarama
# Processing city #flinders
# Processing city #bejar
# Processing city #luba
# Processing city #huaihua
# Processing city #dauphin
# Processing city #inverell
# Processing city #fare
# Processing city #port-cartier
# Processing city #vardo
# Processing city #honiara
# Processing city #stratham
# Processing city #namibe
# Processing city #luxor
# Processing city #belaya gora
# Processing city #ippy
# Processing city #egvekinot
# Processing city #timizart
# Processing city #maymyo
# Processing city #zeya
# Processing city #alibag
# Processing city #nerchinskiy zavod
# Processing city #ereymentau
# City not found. Skipping ...
# Processing city #bilibino
# Processing city #dawson
# Processing city #filingue
# Processing city #tiksi
# Processing city #muscat
# Processing city #indian head
# Processing city #kalmunai
# Processing city #hachinohe
# Processing city #cortez
# Processing city #visby
# Processing city #nanakuli
# Processing city #baghdad
# Processing city #anadyr
# Processing city #puri
# Processing city #coquimbo
# Processing city #muskogee
# Processing city #yangambi
# Processing city #milkovo
# Processing city #san-pedro
# Processing city #urusha
# Processing city #maniitsoq
# Processing city #kattivakkam
# Processing city #tame
# Processing city #laives
# Processing city #celestun
# Processing city #nushki
# Processing city #acarau
# Processing city #paka
# Processing city #okhotsk
# Processing city #korla
# Processing city #praya
# Processing city #olafsvik
# Processing city #sikonge
# Processing city #puerto suarez
# Processing city #liverpool
# Processing city #garden acres
# City not found. Skipping ...
# City not found. Skipping ...
# Processing city #taft
# Processing city #carutapera
# Processing city #boguchany
# Processing city #yumen
# Processing city #lazaro cardenas
# Processing city #kiama
# Processing city #lichinga
# Processing city #zakamensk
# Processing city #kushima
# Processing city #azare
# Processing city #okato
# Processing city #samarai
# Processing city #penzance
# Processing city #plettenberg bay
# Processing city #port hedland
# Processing city #tighina
# City not found. Skipping ...
# Processing city #hagonoy
# Processing city #estelle
# Processing city #yarada
# Processing city #innisfail
# Processing city #bonfim
# Processing city #urbana
# Processing city #mayor pablo lagerenza
# City not found. Skipping ...
# Processing city #itarema
# Processing city #acari
# Processing city #conway
# Processing city #khorramshahr
# Processing city #bucerias
# Processing city #namatanai
# Processing city #itupiranga
# Processing city #anshun
# Processing city #amlame
# Processing city #bandarbeyla
# Processing city #gazanjyk
# City not found. Skipping ...
# Processing city #ganganagar
# Processing city #rio tuba
# City not found. Skipping ...
# Processing city #norsup
# Processing city #kutum
# Processing city #newport
# Processing city #kuragino
# Processing city #yaan
# Processing city #venustiano carranza
# Processing city #ornskoldsvik
# Processing city #palmer
# Processing city #kirakira
# Processing city #voloshka
# Processing city #batemans bay
# Processing city #ingham
# Processing city #stykkisholmur
# Processing city #rio pomba
# Processing city #banda aceh
# Processing city #san borja
# Processing city #bluefield
# City not found. Skipping ...
# Processing city #concepcion del oro
# Processing city #alexandria
# City not found. Skipping ...
# Processing city #ajnala
# Processing city #ribeira brava
# Processing city #yulara
# Processing city #hirara
# Processing city #yavatmal

# %%
city_data_df = pd.DataFrame(cities_arr)
city_data_df.count()
# Out:
# City           706
# Lat            706
# Lng            706
# Main           706
# Description    706
# Temperature    706
# Pressure       706
# Humidity       706
# Min Temp       706
# Max Temp       706
# Wind Speed     706
# Wind Deg       706
# Cloud Layer    706
# Country        706
# Date           706
# dtype: int64

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
city_data_df.describe()
# Out:
#               Lat         Lng  Temperature     Pressure    Humidity  \
# count  706.000000  706.000000   706.000000   706.000000  706.000000
# mean    20.515921   16.301601    67.301416  1011.896601   71.474504
# std     34.364029   93.287053    13.857582     6.963884   20.074543
# min    -54.800000 -179.170000    33.390000   971.000000    3.000000
# 25%     -8.770000  -64.925000    57.200000  1008.000000   60.000000
# 50%     26.235000   18.675000    69.775000  1011.000000   76.500000
# 75%     50.255000  100.050000    78.370000  1016.000000   87.000000
# max     78.220000  179.320000   107.280000  1031.000000  100.000000
#
#          Min Temp    Max Temp  Wind Speed    Wind Deg  Cloud Layer  \
# count  706.000000  706.000000  706.000000  706.000000   706.000000
# mean    66.779943   67.817295    7.657295  181.317280    52.334278
# std     13.772324   14.048762    5.277525  104.378179    36.633766
# min     33.010000   33.800000    0.310000    0.000000     0.000000
# 25%     55.990000   57.200000    3.360000   95.250000    17.250000
# 50%     69.290000   69.955000    6.420000  190.000000    59.000000
# 75%     77.227500   78.800000   11.047500  260.000000    90.000000
# max    106.000000  109.000000   33.330000  360.000000   100.000000
#
#                Date
# count  7.060000e+02
# mean   1.594599e+09
# std    2.364394e+02
# min    1.594598e+09
# 25%    1.594598e+09
# 50%    1.594599e+09
# 75%    1.594599e+09
# max    1.594599e+09

# %%
city_data_df.head(25)
# Out:
#                  City    Lat     Lng     Main       Description  Temperature  \
# 0                auki  -8.77  160.70     Rain        light rain        84.13
# 1        kristiansund  63.11    7.73   Clouds  scattered clouds        50.00
# 2                kaeo -35.10  173.78     Rain        light rain        57.99
# 3             rikitea -23.12 -134.97    Clear         clear sky        71.22
# 4              castro -24.79  -50.01    Clear         clear sky        58.78
# 5     arraial do cabo -22.97  -42.03   Clouds     broken clouds        72.99
# 6               demba  -5.51   22.27   Clouds     broken clouds        68.00
# 7   sao joao da barra -21.64  -41.05   Clouds     broken clouds        71.87
# 8              barrow  71.29 -156.79   Clouds   overcast clouds        39.20
# 9             mataura -46.19  168.86   Clouds   overcast clouds        42.94
# 10      saint anthony  45.02  -93.22   Clouds        few clouds        81.77
# 11            qaanaaq  77.48  -69.36   Clouds     broken clouds        45.91
# 12            darlawn  24.02   92.90   Clouds   overcast clouds        68.22
# 13      pangkalanbuun  -2.68  111.62   Clouds   overcast clouds        74.32
# 14            canning  22.32   88.67     Haze              haze        80.60
# 15          shubarshi  48.59   57.19   Clouds     broken clouds        83.50
# 16               chuy -33.70  -53.46   Clouds  scattered clouds        44.87
# 17          sovetskiy  61.36   63.58   Clouds  scattered clouds        64.47
# 18          jamestown  42.10  -79.24   Clouds  scattered clouds        72.18
# 19        new norfolk -42.78  147.06    Clear         clear sky        40.42
# 20          ostrovnoy  68.05   39.51   Clouds   overcast clouds        47.71
# 21           carballo  43.21   -8.69    Clear         clear sky        61.56
# 22            mawlaik  23.63   94.42     Rain     moderate rain        76.26
# 23          kingisepp  59.37   28.61   Clouds  scattered clouds        49.44
# 24            husavik  66.04  -17.34  Drizzle           drizzle        51.80
#
#     Pressure  Humidity  Min Temp  Max Temp  Wind Speed  Wind Deg  Cloud Layer  \
# 0       1010        71     84.13     84.13        6.71       102           88
# 1       1019        81     50.00     50.00       13.87       240           35
# 2       1026         3     57.99     57.99        7.00       327           43
# 3       1019        72     71.22     71.22       15.03        65            3
# 4       1016        84     58.78     58.78        5.41       311            4
# 5       1015        78     72.99     72.99       15.68        24           69
# 6       1011        86     68.00     68.00        1.32       253           63
# 7       1017        85     71.87     71.87       17.29        25           81
# 8       1009        80     39.20     39.20        6.93        30           90
# 9       1024        86     42.94     42.94        3.98       298           86
# 10      1013        37     80.01     82.99        3.36        60           20
# 11      1008        63     45.91     45.91        3.13       242           82
# 12      1004       100     68.22     68.22        1.83       139          100
# 13      1010        94     74.32     74.32        3.36        63           90
# 14       999        94     80.60     80.60        6.11       236           75
# 15      1012        32     83.50     83.50        4.47       130           57
# 16      1014        66     44.87     44.87        9.93       252           40
# 17      1009        72     64.47     64.47        7.56       291           48
# 18      1010        68     71.60     73.00       11.41       300           40
# 19      1030        91     37.99     43.00        1.68       310            0
# 20      1016        91     47.71     47.71        7.61       344          100
# 21      1023        77     60.01     64.40        5.82        10            0
# 22      1004        95     76.26     76.26        2.55       183          100
# 23      1016        94     49.44     49.44        2.53       204           35
# 24      1008        93     51.80     51.80        3.36       340           40
#
#    Country        Date
# 0       SB  1594598283
# 1       NO  1594598283
# 2       NZ  1594598255
# 3       PF  1594598231
# 4       BR  1594598283
# 5       BR  1594598185
# 6       CD  1594598284
# 7       BR  1594598284
# 8       US  1594598284
# 9       NZ  1594598284
# 10      US  1594598074
# 11      GL  1594598285
# 12      IN  1594598285
# 13      ID  1594598131
# 14      IN  1594598285
# 15      KZ  1594598286
# 16      UY  1594598286
# 17      RU  1594598286
# 18      US  1594598130
# 19      AU  1594598071
# 20      RU  1594598074
# 21      ES  1594598287
# 22      MM  1594598287
# 23      RU  1594598288
# 24      IS  1594598167

# %%
#  Get the indices of cities that have humidity over 100%.

cities_humidity_100 = city_data_df[(city_data_df['Humidity'] > 100)].index

###Proof of concept - outliers exist for humidity over 80
#cities_humidity_80 = city_data_df[(city_data_df['Humidity'] > 80)].index

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

cities_humidity_100 = city_data_df[(city_data_df['Humidity'] > 100)]
cities_humidity_100

###Proof of concept - outliers exist for humidity over 80
#cities_humidity_80 = city_data_df[(city_data_df['Humidity'] > 80)]
#cities_humidity_80
# Out:
# Empty DataFrame
# Columns: [City, Lat, Lng, Main, Description, Temperature, Pressure, Humidity, Min Temp, Max Temp, Wind Speed, Wind Deg, Cloud Layer, Country, Date]
# Index: []

# %%
# Extract relevant fields from the data frame

# Export the City_Data into a csv

city_data_df.to_csv("city_data_df")

###https://stackoverflow.com/questions/49215252/drop-indexes-from-a-huge-pandas-dataframe-that-cannot-possibly-fit-in-memory
###df = df.drop(df.index[example_ix_list])

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
x_values = city_data_df["Lat"]
y_values = city_data_df["Temperature"]
plt.scatter(x_values,y_values,facecolors="red")
plt.title("Latitude vs. Temperature (F) Plot")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
plt.grid(True)
plt.show()

#https://stackoverflow.com/questions/20616754/pandas-how-to-display-minor-grid-lines-on-x-axis-in-pd-dataframe-plot
#xtick = pd.date_range( start=ts.index.min( ), end=ts.index.max( ), freq='W' )
#ax.set_xticks( xtick, minor=True )
#ax.grid('on', which='minor', axis='x' )
#ax.grid('off', which='major', axis='x' )

# %%
#Analysis - Temperatures are generally 70F-85F between -20 deg to +40 deg Latitude. Northern hemisphere has many more
#           cities above 70F between 20 deg to 40 deg Lat than Southern Hemisphere cities between -20 deg to -40 deg Lat.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
x_values = city_data_df["Lat"]
y_values = city_data_df["Humidity"]
plt.scatter(x_values,y_values,facecolors="green")
plt.title("Latitude vs. Humidity % Plot")
plt.xlabel("Latitude")
plt.ylabel("Humidity %")
plt.grid(True)
plt.show()

# %%
#Analysis - High humidity exists across the latitude spectrum. Lower humidities (where they exist) are generally found
#           between 15 deg and 45 deg on either side of the equator.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
x_values = city_data_df["Lat"]
y_values = city_data_df["Cloud Layer"]
plt.scatter(x_values,y_values,facecolors="blue")
plt.title("Latitude vs. Cloudiness % Plot")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness %")
plt.grid(True)
plt.show()

# %%
#Analysis - Most cities are stratified at 20% intervals.  No cities within 10 deg of the equator have cloudiness < 20%.
#           In the N. Hemisphere 20 deg to 40 deg, most cities are either <= 40% or >= 75% cloudiness (60% is empty).

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
x_values = city_data_df["Lat"]
y_values = city_data_df["Wind Speed"]
plt.scatter(x_values,y_values,facecolors="purple")
plt.title("Latitude vs. Wind Speed (mph) Plot")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(True)
plt.show()

# %%
#Analysis - Most cities in either hemisphere have wind speeds <= 12 mph.  Cities with wind speed above 12 mph have a
#           higher likelihood of being 20+ degrees or more away from the equator on either side.  All cities with wind
#           speed above 20 mph are within 39 deg of the equator.

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

#def regrs(ax):
#    (slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
#    regress_values = x_values * slope + intercept
#    #print(regress_values)
#    
#    line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
#    #print(line_eq)
#regrs

# %%
# Create Northern and Southern Hemisphere DataFrames

city_data_nh = city_data_df[(city_data_df['Lat'] > 0)]
city_data_sh = city_data_df[(city_data_df['Lat'] < 0)]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = city_data_nh["Lat"]
y_values = city_data_nh["Max Temp"]

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

plt.scatter(x_values,y_values,facecolors="green")
plt.plot(x_values,regress_values,"r-")

plt.title("Max Temp (F) vs Latitude - Northern Hemisphere")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.annotate(line_eq,(40,100),fontsize=15,color="black")
plt.grid(True)

print(f"The r-squared is: {rvalue**2}")
print(f"The slope & y-intercept equation is {line_eq}")

plt.show()
# Out:
# The r-squared is: 0.42329035140348853
# The slope & y-intercept equation is y = -0.44x +87.65

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = city_data_sh["Lat"]
y_values = city_data_sh["Max Temp"]

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

plt.scatter(x_values,y_values,facecolors="brown")
plt.plot(x_values,regress_values,"r-")

plt.title("Max Temp (F) vs Latitude - Southern Hemisphere")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.annotate(line_eq,(-50,80),fontsize=15,color="black")
plt.grid(True)

print(f"The r-squared is: {rvalue**2}")
print(f"The slope & y-intercept equation is {line_eq}")

plt.show()
# Out:
# The r-squared is: 0.7106421961970332
# The slope & y-intercept equation is y = 0.83x +81.33

# %%
#Analysis - N.Hem. Max Temp regression line at 25 deg Lat is approx 77F. S.Hem at -25 deg Lat is approx 61F.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = city_data_nh["Lat"]
y_values = city_data_nh["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

plt.scatter(x_values,y_values,facecolors="green")
plt.plot(x_values,regress_values,"r-")

plt.title("Humidity (%) vs Latitude - Northern Hemisphere")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.annotate(line_eq,(0,15),fontsize=15,color="black")
plt.grid(True)

print(f"The r-squared is: {rvalue**2}")
print(f"The slope & y-intercept equation is {line_eq}")

plt.show()
# Out:
# The r-squared is: 0.006883756414250542
# The slope & y-intercept equation is y = -0.09x +73.99

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = city_data_sh["Lat"]
y_values = city_data_sh["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

plt.scatter(x_values,y_values,facecolors="brown")
plt.plot(x_values,regress_values,"r-")

plt.title("Humidity (%) vs Latitude - Southern Hemisphere")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.annotate(line_eq,(-50,20),fontsize=15,color="black")
plt.grid(True)

print(f"The r-squared is: {rvalue**2}")
print(f"The slope & y-intercept equation is {line_eq}")

plt.show()
# Out:
# The r-squared is: 0.010009032799640147
# The slope & y-intercept equation is y = 0.13x +76.48

# %%
#Analysis - N.Hem. Humidity regression line at 25 deg Lat is approx 72%. S.Hem at -25 deg Lat is approx 73%.
#           N.Hem. Humidity regression line at 55 deg Lat is approx 69%. S.Hem at -55 deg Lat is approx 69%.
#           Both hemispheres have roughly the same Humidity regression.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = city_data_nh["Lat"]
y_values = city_data_nh["Cloud Layer"]

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

plt.scatter(x_values,y_values,facecolors="green")
plt.plot(x_values,regress_values,"r-")

plt.title("Cloudiness (%) vs Latitude - Northern Hemisphere")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.annotate(line_eq,(10,30),fontsize=15,color="black")
plt.grid(True)

print(f"The r-squared is: {rvalue**2}")
print(f"The slope & y-intercept equation is {line_eq}")

plt.show()
# Out:
# The r-squared is: 0.0003672057557854109
# The slope & y-intercept equation is y = 0.03x +51.68

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = city_data_sh["Lat"]
y_values = city_data_sh["Cloud Layer"]

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

plt.scatter(x_values,y_values,facecolors="brown")
plt.plot(x_values,regress_values,"r-")

plt.title("Cloudiness (%) vs Latitude - Southern Hemisphere")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.annotate(line_eq,(-55,25),fontsize=15,color="black")
plt.grid(True)

print(f"The r-squared is: {rvalue**2}")
print(f"The slope & y-intercept equation is {line_eq}")

plt.show()
# Out:
# The r-squared is: 0.053592196211998434
# The slope & y-intercept equation is y = 0.6x +64.49

# %%
#Analysis - The Cloudiness(%) 0.6 slope for the S. Hem. is steeper than the N. Hem. 0.03 slope.
#           At -25 deg Lat, the Cloudiness(%) is approx 49%, vs approx 52% in the N. Hem.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = city_data_nh["Lat"]
y_values = city_data_nh["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

plt.scatter(x_values,y_values,facecolors="green")
plt.plot(x_values,regress_values,"r-")

plt.title("Wind Speed (%) vs Latitude - Northern Hemisphere")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (%)')
plt.annotate(line_eq,(40,25),fontsize=15,color="black")
plt.grid(True)

print(f"The r-squared is: {rvalue**2}")
print(f"The slope & y-intercept equation is {line_eq}")

plt.show()
# Out:
# The r-squared is: 0.0029022023639732066
# The slope & y-intercept equation is y = -0.01x +7.77

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = city_data_sh["Lat"]
y_values = city_data_sh["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

plt.scatter(x_values,y_values,facecolors="brown")
plt.plot(x_values,regress_values,"r-")

plt.title("Wind Speed (%) vs Latitude - Southern Hemisphere")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (%)')
plt.annotate(line_eq,(-25,30),fontsize=15,color="black")
plt.grid(True)

print(f"The r-squared is: {rvalue**2}")
print(f"The slope & y-intercept equation is {line_eq}")

plt.show()
# Out:
# The r-squared is: 0.0290012431807387
# The slope & y-intercept equation is y = -0.08x +6.83

# %%
#Analysis - N. Hem. has very little change in wind relative to latitude (slope = 0.01).  7.77 Y-intercept is driver of N.
#           Hem. Wind Speed.  S. Hem. Wind Speed is also driven by Y-intercept 6.83 as -0.08 slope is a very gradual
#           increase toward the S. Pole.
